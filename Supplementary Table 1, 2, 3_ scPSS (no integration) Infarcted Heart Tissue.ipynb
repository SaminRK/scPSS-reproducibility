# %% [markdown]
# This is run a Google Colab Notebook

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Downloading files

# %%
# !wget --header="Host: www.ncbi.nlm.nih.gov" --header="User-Agent: Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/112.0.0.0 Safari/537.36" --header="Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7" --header="Accept-Language: en-GB,en;q=0.9,en-US;q=0.8,bn;q=0.7" --header="Referer: https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE214611" --header="Cookie: _gid=GA1.2.843222926.1683780721; ncbi_sid=0C4234AB45C74711_0000SID; _ga=GA1.1.1244755766.1683780721; _ga_DP2X732JSX=GS1.1.1683780720.1.1.1683782404.0.0.0; _gat_ncbiSg=1; ncbi_pinger=..." --header="Connection: keep-alive" "https://www.ncbi.nlm.nih.gov/geo/download/?acc=GSE214611&format=file" -c -O '/content/drive/MyDrive/Samin/PathologicalCells/data/GSE214611_RAW.tar'

# %%
# !tar -xvf '/content/drive/MyDrive/Samin/PathologicalCells/data/GSE214611_RAW.tar' -C '/content/drive/MyDrive/Samin/PathologicalCells/data/GSE214611_RAW/'

# %%
# !cd '/content/drive/MyDrive/Samin/PathologicalCells/data/GSE214611_RAW/' && for f in *.tar.gz; do tar -xvzf "$f" -C "$(dirname "$f")"; done

# %%
# !unzip '/content/drive/MyDrive/Samin/PathologicalCells/data/GSE214611_RAW/Single-Cell-Spatial-Transcriptomics-for-Border-zone-BZ_Cell_Mapping.zip' -d '/content/drive/MyDrive/Samin/PathologicalCells/data/GSE214611_RAW'

# %% [markdown]
# ## scPSS

# %%
# !pip install git+https://github.com/SaminRK/scPSS.git
# Out:
# Collecting git+https://github.com/SaminRK/scPSS.git
#   Cloning https://github.com/SaminRK/scPSS.git to /tmp/pip-req-build-ysh0vn37
#   Running command git clone --filter=blob:none --quiet https://github.com/SaminRK/scPSS.git /tmp/pip-req-build-ysh0vn37
#   Resolved https://github.com/SaminRK/scPSS.git to commit 28c1e6d9a4bbc44848e47d23d7221a29e30e8820
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from scPSS==0.1.1) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from scPSS==0.1.1) (2.2.2)
# Collecting scanpy==1.11.1 (from scPSS==0.1.1)
#   Downloading scanpy-1.11.1-py3-none-any.whl.metadata (9.9 kB)
# Collecting anndata==0.10.3 (from scPSS==0.1.1)
#   Downloading anndata-0.10.3-py3-none-any.whl.metadata (6.4 kB)
# Collecting harmonypy (from scPSS==0.1.1)
#   Downloading harmonypy-0.0.10-py3-none-any.whl.metadata (3.9 kB)
# Collecting kneed (from scPSS==0.1.1)
#   Downloading kneed-0.8.5-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from scPSS==0.1.1) (3.10.0)
# Collecting array-api-compat (from anndata==0.10.3->scPSS==0.1.1)
#   Downloading array_api_compat-1.12.0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: h5py>=3 in /usr/local/lib/python3.11/dist-packages (from anndata==0.10.3->scPSS==0.1.1) (3.13.0)
# Requirement already satisfied: natsort in /usr/local/lib/python3.11/dist-packages (from anndata==0.10.3->scPSS==0.1.1) (8.4.0)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.11/dist-packages (from anndata==0.10.3->scPSS==0.1.1) (24.2)
# Requirement already satisfied: scipy>1.4 in /usr/local/lib/python3.11/dist-packages (from anndata==0.10.3->scPSS==0.1.1) (1.15.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from scanpy==1.11.1->scPSS==0.1.1) (1.5.1)
# Collecting legacy-api-wrap>=1.4 (from scanpy==1.11.1->scPSS==0.1.1)
#   Downloading legacy_api_wrap-1.4.1-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: networkx>=2.7 in /usr/local/lib/python3.11/dist-packages (from scanpy==1.11.1->scPSS==0.1.1) (3.5)
# Requirement already satisfied: numba>=0.57 in /usr/local/lib/python3.11/dist-packages (from scanpy==1.11.1->scPSS==0.1.1) (0.60.0)
# Requirement already satisfied: patsy!=1.0.0 in /usr/local/lib/python3.11/dist-packages (from scanpy==1.11.1->scPSS==0.1.1) (1.0.1)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.11/dist-packages (from scanpy==1.11.1->scPSS==0.1.1) (0.5.13)
# Collecting scikit-learn<1.6.0,>=1.1 (from scanpy==1.11.1->scPSS==0.1.1)
#   Downloading scikit_learn-1.5.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: seaborn>=0.13 in /usr/local/lib/python3.11/dist-packages (from scanpy==1.11.1->scPSS==0.1.1) (0.13.2)
# Collecting session-info2 (from scanpy==1.11.1->scPSS==0.1.1)
#   Downloading session_info2-0.1.2-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: statsmodels>=0.13 in /usr/local/lib/python3.11/dist-packages (from scanpy==1.11.1->scPSS==0.1.1) (0.14.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from scanpy==1.11.1->scPSS==0.1.1) (4.67.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from scanpy==1.11.1->scPSS==0.1.1) (4.14.0)
# Requirement already satisfied: umap-learn!=0.5.0,>=0.5 in /usr/local/lib/python3.11/dist-packages (from scanpy==1.11.1->scPSS==0.1.1) (0.5.7)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->scPSS==0.1.1) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->scPSS==0.1.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->scPSS==0.1.1) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->scPSS==0.1.1) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->scPSS==0.1.1) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->scPSS==0.1.1) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->scPSS==0.1.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->scPSS==0.1.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->scPSS==0.1.1) (2025.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.57->scanpy==1.11.1->scPSS==0.1.1) (0.43.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->scPSS==0.1.1) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<1.6.0,>=1.1->scanpy==1.11.1->scPSS==0.1.1) (3.6.0)
# Downloading anndata-0.10.3-py3-none-any.whl (119 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.2/119.2 kB 3.3 MB/s eta 0:00:00
# Downloading scanpy-1.11.1-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 33.7 MB/s eta 0:00:00
# Downloading harmonypy-0.0.10-py3-none-any.whl (20 kB)
# Downloading kneed-0.8.5-py3-none-any.whl (10 kB)
# Downloading legacy_api_wrap-1.4.1-py3-none-any.whl (10.0 kB)
# Downloading scikit_learn-1.5.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 100.0 MB/s eta 0:00:00
# Downloading array_api_compat-1.12.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.2/58.2 kB 4.4 MB/s eta 0:00:00
# Downloading session_info2-0.1.2-py3-none-any.whl (14 kB)
# Building wheels for collected packages: scPSS
#   Building wheel for scPSS (pyproject.toml) ... done
#   Created wheel for scPSS: filename=scpss-0.1.1-py3-none-any.whl size=7225 sha256=3969a5f17335a5f535e73030a8806f54452df2642eb8b76ee92de765511e9646
#   Stored in directory: /tmp/pip-ephem-wheel-cache-cx7h8hfp/wheels/38/a1/b0/2c6e36cd72b420c8578046e45e829c13592ad572cc99e9a8f1
# Successfully built scPSS
# Installing collected packages: session-info2, legacy-api-wrap, array-api-compat, scikit-learn, kneed, harmonypy, anndata, scanpy, scPSS
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.6.1
#     Uninstalling scikit-learn-1.6.1:
#       Successfully uninstalled scikit-learn-1.6.1
# Successfully installed anndata-0.10.3 array-api-compat-1.12.0 harmonypy-0.0.10 kneed-0.8.5 legacy-api-wrap-1.4.1 scPSS-0.1.1 scanpy-1.11.1 scikit-learn-1.5.2 session-info2-0.1.2

# %%
## Modify to the source directory of single cell data
ROOT_PATH = '/content/drive/MyDrive/Research - Sohel sir/Pathological Cells/Pathological Cell Identification/data/Infracted Heart Border Zone - GSE214611_RAW'

# %%
import scanpy as sc
import pandas as pd

# %%
metadata_sc = pd.read_csv(f'{ROOT_PATH}/Single-Cell-Spatial-Transcriptomics-for-Border-zone/sn_wc_object_integrated@meta.data.csv', index_col=0)
metadata_sc_t = metadata_sc.rename(index=lambda x: x.split('_')[0])
metadata_sc_t['obs_names'] = metadata_sc_t.index

# %%
def get_anndata(mtx_path_id, metadata_orig_id):
    PATH = f'{ROOT_PATH}/{mtx_path_id}'
    ad = sc.read_10x_mtx(PATH)
    ad.obs = ad.obs.rename(index=lambda x: x.split('-')[0])
    A = metadata_sc_t[metadata_sc_t['orig.ident'] == metadata_orig_id]

    ad.obs = ad.obs.merge(A, left_index=True, right_index=True, how='left')

    return ad

# %%
def pp_anndata(ad, n_top_genes=None, plot=False):
    ad.var_names_make_unique()

    sc.pp.filter_cells(ad, min_genes=200)
    sc.pp.filter_genes(ad, min_cells=3)

    ad.var['mt'] = ad.var_names.str.startswith('mt-')
    sc.pp.calculate_qc_metrics(ad, qc_vars=['mt'], percent_top=None, log1p=False, inplace=True)
    if plot:
        sc.pl.violin(ad, ['n_genes_by_counts', 'total_counts', 'pct_counts_mt'],
                jitter=0.4, multi_panel=True)
        sc.pl.scatter(ad, x='total_counts', y='pct_counts_mt')
        sc.pl.scatter(ad, x='total_counts', y='n_genes_by_counts')

    ad = ad[ad.obs.pct_counts_mt <= 5, :]

    sc.pp.normalize_total(ad, target_sum=1e4)
    sc.pp.log1p(ad)

    if n_top_genes is not None:
        sc.pp.highly_variable_genes(ad, n_top_genes=n_top_genes)
        ad.raw = ad
        ad = ad[:, ad.var.highly_variable]

    if plot:
        sc.pl.highly_variable_genes(ad)

    return ad

# %% [markdown]
# ## Prepare training and testing dataset

# %%
def get_mtx_path_id_metadata_orig_id(problem_key):
    exp_meta_keys = {
        'ref_0_que_1hr': {
            'reference': [
                ('snd0_1', 'D0'),
                ('snd0_2', 'D0'),
                ('snd0_3', 'NoMI_Nuclei'),
            ],
            'query': [
                ('sn1hr_1', 'sn1_1'),
                ('sn1hr_2', 'sn1_2'),
            ]
        },
        'ref_0_que_4hr': {
            'reference': [
                ('snd0_1', 'D0'),
                ('snd0_2', 'D0'),
                ('snd0_3', 'NoMI_Nuclei'),
            ],
            'query': [
                ('sn4hr', '4HR'),
            ]
        },
        'ref_0_que_1': {
            'reference': [
                ('snd0_1', 'D0'),
                ('snd0_2', 'D0'),
                ('snd0_3', 'NoMI_Nuclei'),
            ],
            'query': [
                ('snd1_1', 'D1_MI'),
                ('snd1_2', 'D1_MI_Hrt_nuclei'),
                ('snd1_3', 'D1_IR30_Hrt_nuclei'),
                ('snd1_4', 'WT_IR30_D1_2'),
                ('snd1_5', 'WT_IR30_D1_3'),
            ]
        },
        'ref_0_que_3': {
            'reference': [
                ('snd0_1', 'D0'),
                ('snd0_2', 'D0'),
                ('snd0_3', 'NoMI_Nuclei'),
            ],
            'query': [
                ('snd3_1', 'WT_IR30_D3'),
                ('snd3_2', 'D3F_M_rep1'),
                ('snd3_3', 'D3F_M_rep2'),
            ]
        },
        'ref_0_que_7': {
            'reference': [
                ('snd0_1', 'D0'),
                ('snd0_2', 'D0'),
                ('snd0_3', 'NoMI_Nuclei'),
            ],
            'query': [
                ('snd7_1', 'snD7_1'),
                ('snd7_2', 'snD7_1'),
                ('snd7_3', 'D5_D7'),
            ]
        },
        'ref_0_que_1-7': {
            'reference': [
                ('snd0_1', 'D0'),
                ('snd0_2', 'D0'),
                ('snd0_3', 'NoMI_Nuclei'),
            ],
            'query': [
                ('sn1hr_1', 'sn1_1'),
                ('sn1hr_2', 'sn1_2'),
                ('sn4hr', '4HR'),
                ('snd1_1', 'D1_MI'),
                ('snd1_2', 'D1_MI_Hrt_nuclei'),
                ('snd1_3', 'D1_IR30_Hrt_nuclei'),
                ('snd1_4', 'WT_IR30_D1_2'),
                ('snd1_5', 'WT_IR30_D1_3'),
                ('snd3_1', 'WT_IR30_D3'),
                ('snd3_2', 'D3F_M_rep1'),
                ('snd3_3', 'D3F_M_rep2'),
                ('snd7_1', 'snD7_1'),
                ('snd7_2', 'snD7_1'),
                ('snd7_3', 'D5_D7'),
            ]
        }
    }

    return exp_meta_keys[problem_key]

# %%
import anndata as AD

imp_celltypes = ['Ankrd1', 'Xirp2', 'Myh6']


def get_ad(PROBLEM_KEY, n_top_genes=None):

    exp_meta_keys = get_mtx_path_id_metadata_orig_id(PROBLEM_KEY)

    adatas = {}

    for key, item in exp_meta_keys.items():
        for i, (mtx_path_id, metadata_orig_id) in enumerate(item):
            ad = pp_anndata(get_anndata(mtx_path_id, metadata_orig_id))
            ad = ad[ad.obs['final_cluster'].isin(imp_celltypes)]
            dataset_id = f"{key}_{i+1}"
            ad.obs['sample'] = dataset_id
            ad.obs['dataset'] = key
            adatas[f"{key}_{i+1}"] = ad

    ad = AD.concat(adatas, label='batch_key')
    ad.obs_names_make_unique()

    cluster_to_zone = {
        "Ankrd1": "BZ1",
        "Xirp2": "BZ2",
        "Myh6": "RZ",
    }

    ad.obs["zone"] = ad.obs["final_cluster"].map(cluster_to_zone)

    if n_top_genes is not None and n_top_genes < ad.shape[1]:
        sc.pp.highly_variable_genes(ad, n_top_genes=n_top_genes)
        ad.raw = ad
        ad = ad[:, ad.var.highly_variable]

    return ad

# %%
## Modify to the directory where outputs should be stored
OUT_PATH = "/content/drive/MyDrive/Research - Sohel sir/Pathological Cells/Pathological Cell Identification/reproducibility/outputs"
metrics_csv_path = f"{OUT_PATH}/scpss-mouse-infarcted-heart-metrics-pca.csv"
results_csv_path = f"{OUT_PATH}/scpss-mouse-infarcted-heart-results-pca.csv"

# %%
from scpss import scPSS
import time
import numpy as np


with open(metrics_csv_path, 'w') as f:
    print('PROBLEM_KEY', 'seed', 'accuracy', 'precision', 'recall', 'f1', 'auc', 'aupr', 'outlier_ratio_ref', 'outlier_ratio_que', 'time_taken',  sep=',', file=f, flush=True)


    for PROBLEM_KEY in ['ref_0_que_1hr', 'ref_0_que_4hr', 'ref_0_que_1', 'ref_0_que_3', 'ref_0_que_7',  'ref_0_que_1-7']:
        ad = get_ad(PROBLEM_KEY, n_top_genes=5000)

        reference_samples = list(ad.obs[ad.obs['dataset'] == 'reference']['sample'].unique())
        query_samples = list(ad.obs[ad.obs['dataset'] == 'query']['sample'].unique())


        for i in range(3):
            print('RUN: ', i)
            seed = i * 100

            start_time = time.perf_counter()

            scpss = scPSS(ad.copy(), 'sample', reference_samples, query_samples)

            sc.pp.pca(scpss.adata)

            scpss.__obsm_str__ = 'X_pca'

            scpss.find_optimal_parameters()
            scpss.set_distance_and_condition()

            end_time = time.perf_counter()

            ad_que = scpss.adata[scpss.query_mask]

            true_labels = ad_que.obs['zone'].isin(['BZ1', 'BZ2']).to_numpy()
            predicted_labels = ad_que.obs['scpss_condition'].isin(['diseased']).to_numpy()
            dist_que_ref = scpss.adata.obs.loc[scpss.query_mask, 'scpss_distances']
            dist_ref_ref = scpss.adata.obs.loc[scpss.reference_mask, 'scpss_distances']

            time_taken = end_time - start_time


            from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

            accuracy = accuracy_score(true_labels, predicted_labels)
            precision = precision_score(true_labels, predicted_labels)
            recall = recall_score(true_labels, predicted_labels)
            f1 = f1_score(true_labels, predicted_labels)

            print("Accuracy:", accuracy)
            print("Precision:", precision)
            print("Recall:", recall)
            print("F1-score:", f1)

            from sklearn.metrics import roc_auc_score, average_precision_score
            from sklearn.metrics import roc_curve, precision_recall_curve

            y_true = true_labels
            y_scores = dist_que_ref

            auc = roc_auc_score(y_true, y_scores)
            print("AUC:", auc)

            aupr = average_precision_score(y_true, y_scores)
            print("AUPR:", aupr)

            outlier_ratio_ref = np.mean(dist_ref_ref > scpss.best_params['threshold'])
            print("Outlier ratio in reference:", outlier_ratio_ref)
            outlier_ratio_que = np.mean(dist_que_ref > scpss.best_params['threshold'])
            print("Outlier ratio in query:", outlier_ratio_que)


            print(PROBLEM_KEY, seed, accuracy, precision, recall, f1, auc, aupr, outlier_ratio_ref, outlier_ratio_que, time_taken, sep=',', file=f, flush=True)
# Out:
# /usr/local/lib/python3.11/dist-packages/scanpy/preprocessing/_normalization.py:216: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# <ipython-input-11-746900811>:17: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   ad.obs['sample'] = dataset_id
# /usr/local/lib/python3.11/dist-packages/scanpy/preprocessing/_normalization.py:216: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# <ipython-input-11-746900811>:17: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   ad.obs['sample'] = dataset_id
# /usr/local/lib/python3.11/dist-packages/scanpy/preprocessing/_normalization.py:216: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# <ipython-input-11-746900811>:17: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   ad.obs['sample'] = dataset_id
# /usr/local/lib/python3.11/dist-packages/scanpy/preprocessing/_normalization.py:216: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# <ipython-input-11-746900811>:17: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   ad.obs['sample'] = dataset_id
# /usr/local/lib/python3.11/dist-packages/scanpy/preprocessing/_normalization.py:216: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# <ipython-input-11-746900811>:17: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   ad.obs['sample'] = dataset_id
# /usr/local/lib/python3.11/dist-packages/anndata/_core/anndata.py:1897: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# RUN:  0
# ✅ Found Optimal Parameters.
# ✅ Stored distances and conditions in Anndata object.
# Accuracy: 0.42246555987283646
# Precision: 0.3957793409848204
# Recall: 0.9972014925373134
# F1-score: 0.5666578319639544
# AUC: 0.9032550083578695
# AUPR: 0.8494821357050425
# Outlier ratio in reference: 0.018462469733656173
# Outlier ratio in query: 0.9540798304486048
# RUN:  1
# ✅ Found Optimal Parameters.
# ✅ Stored distances and conditions in Anndata object.
# Accuracy: 0.42246555987283646
# Precision: 0.3957793409848204
# Recall: 0.9972014925373134
# F1-score: 0.5666578319639544
# AUC: 0.9032550083578695
# AUPR: 0.8494821357050425
# Outlier ratio in reference: 0.018462469733656173
# Outlier ratio in query: 0.9540798304486048
# RUN:  2
# ✅ Found Optimal Parameters.
# ✅ Stored distances and conditions in Anndata object.
# Accuracy: 0.42246555987283646
# Precision: 0.3957793409848204
# Recall: 0.9972014925373134
# F1-score: 0.5666578319639544
# AUC: 0.9032550083578695
# AUPR: 0.8494821357050425
# Outlier ratio in reference: 0.018462469733656173
# Outlier ratio in query: 0.9540798304486048
# /usr/local/lib/python3.11/dist-packages/scanpy/preprocessing/_normalization.py:216: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# <ipython-input-11-746900811>:17: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   ad.obs['sample'] = dataset_id
# /usr/local/lib/python3.11/dist-packages/scanpy/preprocessing/_normalization.py:216: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# <ipython-input-11-746900811>:17: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   ad.obs['sample'] = dataset_id
# /usr/local/lib/python3.11/dist-packages/scanpy/preprocessing/_normalization.py:216: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# <ipython-input-11-746900811>:17: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   ad.obs['sample'] = dataset_id
# /usr/local/lib/python3.11/dist-packages/scanpy/preprocessing/_normalization.py:216: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# <ipython-input-11-746900811>:17: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   ad.obs['sample'] = dataset_id
# /usr/local/lib/python3.11/dist-packages/anndata/_core/anndata.py:1897: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# RUN:  0
# ✅ Found Optimal Parameters.
# ✅ Stored distances and conditions in Anndata object.
# Accuracy: 0.6223723723723724
# Precision: 0.6206636500754148
# Recall: 1.0
# F1-score: 0.7659376454164728
# AUC: 0.9485494393743719
# AUPR: 0.9645710721863472
# Outlier ratio in reference: 0.021791767554479417
# Outlier ratio in query: 0.9954954954954955
# RUN:  1
# ✅ Found Optimal Parameters.
# ✅ Stored distances and conditions in Anndata object.
# Accuracy: 0.6223723723723724
# Precision: 0.6206636500754148
# Recall: 1.0
# F1-score: 0.7659376454164728
# AUC: 0.9485494393743719
# AUPR: 0.9645710721863472
# Outlier ratio in reference: 0.021791767554479417
# Outlier ratio in query: 0.9954954954954955
# RUN:  2
# ✅ Found Optimal Parameters.
# ✅ Stored distances and conditions in Anndata object.
# Accuracy: 0.6223723723723724
# Precision: 0.6206636500754148
# Recall: 1.0
# F1-score: 0.7659376454164728
# AUC: 0.9485494393743719
# AUPR: 0.9645710721863472
# Outlier ratio in reference: 0.021791767554479417
# Outlier ratio in query: 0.9954954954954955
# /usr/local/lib/python3.11/dist-packages/scanpy/preprocessing/_normalization.py:216: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# <ipython-input-11-746900811>:17: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   ad.obs['sample'] = dataset_id
# /usr/local/lib/python3.11/dist-packages/scanpy/preprocessing/_normalization.py:216: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# <ipython-input-11-746900811>:17: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   ad.obs['sample'] = dataset_id
# /usr/local/lib/python3.11/dist-packages/scanpy/preprocessing/_normalization.py:216: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# <ipython-input-11-746900811>:17: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   ad.obs['sample'] = dataset_id
# /usr/local/lib/python3.11/dist-packages/scanpy/preprocessing/_normalization.py:216: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# <ipython-input-11-746900811>:17: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   ad.obs['sample'] = dataset_id
# /usr/local/lib/python3.11/dist-packages/scanpy/preprocessing/_normalization.py:216: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# <ipython-input-11-746900811>:17: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   ad.obs['sample'] = dataset_id
# /usr/local/lib/python3.11/dist-packages/scanpy/preprocessing/_normalization.py:216: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# <ipython-input-11-746900811>:17: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   ad.obs['sample'] = dataset_id
# /usr/local/lib/python3.11/dist-packages/scanpy/preprocessing/_normalization.py:216: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# <ipython-input-11-746900811>:17: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   ad.obs['sample'] = dataset_id
# /usr/local/lib/python3.11/dist-packages/scanpy/preprocessing/_normalization.py:216: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# <ipython-input-11-746900811>:17: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   ad.obs['sample'] = dataset_id
# /usr/local/lib/python3.11/dist-packages/anndata/_core/anndata.py:1897: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# RUN:  0
# ✅ Found Optimal Parameters.
# ✅ Stored distances and conditions in Anndata object.
# Accuracy: 0.5718866916087654
# Precision: 0.5570005534034311
# Recall: 0.9995034756703078
# F1-score: 0.7153518123667377
# AUC: 0.9442838211225129
# AUPR: 0.9535630042402798
# Outlier ratio in reference: 0.020278450363196126
# Outlier ratio in query: 0.965793693212186
# RUN:  1
# ✅ Found Optimal Parameters.
# ✅ Stored distances and conditions in Anndata object.
# Accuracy: 0.5718866916087654
# Precision: 0.5570005534034311
# Recall: 0.9995034756703078
# F1-score: 0.7153518123667377
# AUC: 0.9442838211225129
# AUPR: 0.9535630042402798
# Outlier ratio in reference: 0.020278450363196126
# Outlier ratio in query: 0.965793693212186
# RUN:  2
# ✅ Found Optimal Parameters.
# ✅ Stored distances and conditions in Anndata object.
# Accuracy: 0.5718866916087654
# Precision: 0.5570005534034311
# Recall: 0.9995034756703078
# F1-score: 0.7153518123667377
# AUC: 0.9442838211225129
# AUPR: 0.9535630042402798
# Outlier ratio in reference: 0.020278450363196126
# Outlier ratio in query: 0.965793693212186
# /usr/local/lib/python3.11/dist-packages/scanpy/preprocessing/_normalization.py:216: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# <ipython-input-11-746900811>:17: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   ad.obs['sample'] = dataset_id
# /usr/local/lib/python3.11/dist-packages/scanpy/preprocessing/_normalization.py:216: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# <ipython-input-11-746900811>:17: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   ad.obs['sample'] = dataset_id
# /usr/local/lib/python3.11/dist-packages/scanpy/preprocessing/_normalization.py:216: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# <ipython-input-11-746900811>:17: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   ad.obs['sample'] = dataset_id
# /usr/local/lib/python3.11/dist-packages/scanpy/preprocessing/_normalization.py:216: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# <ipython-input-11-746900811>:17: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   ad.obs['sample'] = dataset_id
# /usr/local/lib/python3.11/dist-packages/scanpy/preprocessing/_normalization.py:216: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# <ipython-input-11-746900811>:17: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   ad.obs['sample'] = dataset_id
# /usr/local/lib/python3.11/dist-packages/scanpy/preprocessing/_normalization.py:216: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# <ipython-input-11-746900811>:17: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   ad.obs['sample'] = dataset_id
# /usr/local/lib/python3.11/dist-packages/anndata/_core/anndata.py:1897: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# RUN:  0
# ✅ Found Optimal Parameters.
# ✅ Stored distances and conditions in Anndata object.
# Accuracy: 0.5245769540692989
# Precision: 0.459211732355637
# Recall: 1.0
# F1-score: 0.6293969849246231
# AUC: 0.915471759184334
# AUPR: 0.890008015309143
# Outlier ratio in reference: 0.02602905569007264
# Outlier ratio in query: 0.879129734085415
# RUN:  1
# ✅ Found Optimal Parameters.
# ✅ Stored distances and conditions in Anndata object.
# Accuracy: 0.5245769540692989
# Precision: 0.459211732355637
# Recall: 1.0
# F1-score: 0.6293969849246231
# AUC: 0.915471759184334
# AUPR: 0.890008015309143
# Outlier ratio in reference: 0.02602905569007264
# Outlier ratio in query: 0.879129734085415
# RUN:  2
# ✅ Found Optimal Parameters.
# ✅ Stored distances and conditions in Anndata object.
# Accuracy: 0.5245769540692989
# Precision: 0.459211732355637
# Recall: 1.0
# F1-score: 0.6293969849246231
# AUC: 0.915471759184334
# AUPR: 0.890008015309143
# Outlier ratio in reference: 0.02602905569007264
# Outlier ratio in query: 0.879129734085415
# /usr/local/lib/python3.11/dist-packages/scanpy/preprocessing/_normalization.py:216: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# <ipython-input-11-746900811>:17: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   ad.obs['sample'] = dataset_id
# /usr/local/lib/python3.11/dist-packages/scanpy/preprocessing/_normalization.py:216: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# <ipython-input-11-746900811>:17: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   ad.obs['sample'] = dataset_id
# /usr/local/lib/python3.11/dist-packages/scanpy/preprocessing/_normalization.py:216: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# <ipython-input-11-746900811>:17: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   ad.obs['sample'] = dataset_id
# /usr/local/lib/python3.11/dist-packages/scanpy/preprocessing/_normalization.py:216: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# <ipython-input-11-746900811>:17: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   ad.obs['sample'] = dataset_id
# /usr/local/lib/python3.11/dist-packages/scanpy/preprocessing/_normalization.py:216: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# <ipython-input-11-746900811>:17: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   ad.obs['sample'] = dataset_id
# /usr/local/lib/python3.11/dist-packages/scanpy/preprocessing/_normalization.py:216: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# <ipython-input-11-746900811>:17: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   ad.obs['sample'] = dataset_id
# /usr/local/lib/python3.11/dist-packages/anndata/_core/anndata.py:1897: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# RUN:  0
# ✅ Found Optimal Parameters.
# ✅ Stored distances and conditions in Anndata object.
# Accuracy: 0.5719192786603693
# Precision: 0.5121467526028756
# Recall: 0.9875717017208413
# F1-score: 0.6745021221025139
# AUC: 0.7926242419997347
# AUPR: 0.7705777533358925
# Outlier ratio in reference: 0.024515738498789345
# Outlier ratio in query: 0.8660369257191928
# RUN:  1
# ✅ Found Optimal Parameters.
# ✅ Stored distances and conditions in Anndata object.
# Accuracy: 0.5719192786603693
# Precision: 0.5121467526028756
# Recall: 0.9875717017208413
# F1-score: 0.6745021221025139
# AUC: 0.7926242419997347
# AUPR: 0.7705777533358925
# Outlier ratio in reference: 0.024515738498789345
# Outlier ratio in query: 0.8660369257191928
# RUN:  2
# ✅ Found Optimal Parameters.
# ✅ Stored distances and conditions in Anndata object.
# Accuracy: 0.5719192786603693
# Precision: 0.5121467526028756
# Recall: 0.9875717017208413
# F1-score: 0.6745021221025139
# AUC: 0.7926242419997347
# AUPR: 0.7705777533358925
# Outlier ratio in reference: 0.024515738498789345
# Outlier ratio in query: 0.8660369257191928
# /usr/local/lib/python3.11/dist-packages/scanpy/preprocessing/_normalization.py:216: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# <ipython-input-11-746900811>:17: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   ad.obs['sample'] = dataset_id
# /usr/local/lib/python3.11/dist-packages/scanpy/preprocessing/_normalization.py:216: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# <ipython-input-11-746900811>:17: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   ad.obs['sample'] = dataset_id
# /usr/local/lib/python3.11/dist-packages/scanpy/preprocessing/_normalization.py:216: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# <ipython-input-11-746900811>:17: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   ad.obs['sample'] = dataset_id
# /usr/local/lib/python3.11/dist-packages/scanpy/preprocessing/_normalization.py:216: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# <ipython-input-11-746900811>:17: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   ad.obs['sample'] = dataset_id
# /usr/local/lib/python3.11/dist-packages/scanpy/preprocessing/_normalization.py:216: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# <ipython-input-11-746900811>:17: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   ad.obs['sample'] = dataset_id
# /usr/local/lib/python3.11/dist-packages/scanpy/preprocessing/_normalization.py:216: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# <ipython-input-11-746900811>:17: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   ad.obs['sample'] = dataset_id
# /usr/local/lib/python3.11/dist-packages/scanpy/preprocessing/_normalization.py:216: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# <ipython-input-11-746900811>:17: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   ad.obs['sample'] = dataset_id
# /usr/local/lib/python3.11/dist-packages/scanpy/preprocessing/_normalization.py:216: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# <ipython-input-11-746900811>:17: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   ad.obs['sample'] = dataset_id
# /usr/local/lib/python3.11/dist-packages/scanpy/preprocessing/_normalization.py:216: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# <ipython-input-11-746900811>:17: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   ad.obs['sample'] = dataset_id
# /usr/local/lib/python3.11/dist-packages/scanpy/preprocessing/_normalization.py:216: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# <ipython-input-11-746900811>:17: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   ad.obs['sample'] = dataset_id
# /usr/local/lib/python3.11/dist-packages/scanpy/preprocessing/_normalization.py:216: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# <ipython-input-11-746900811>:17: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   ad.obs['sample'] = dataset_id
# /usr/local/lib/python3.11/dist-packages/scanpy/preprocessing/_normalization.py:216: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# <ipython-input-11-746900811>:17: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   ad.obs['sample'] = dataset_id
# /usr/local/lib/python3.11/dist-packages/scanpy/preprocessing/_normalization.py:216: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# <ipython-input-11-746900811>:17: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   ad.obs['sample'] = dataset_id
# /usr/local/lib/python3.11/dist-packages/scanpy/preprocessing/_normalization.py:216: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# <ipython-input-11-746900811>:17: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   ad.obs['sample'] = dataset_id
# /usr/local/lib/python3.11/dist-packages/scanpy/preprocessing/_normalization.py:216: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# <ipython-input-11-746900811>:17: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   ad.obs['sample'] = dataset_id
# /usr/local/lib/python3.11/dist-packages/scanpy/preprocessing/_normalization.py:216: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# <ipython-input-11-746900811>:17: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   ad.obs['sample'] = dataset_id
# /usr/local/lib/python3.11/dist-packages/scanpy/preprocessing/_normalization.py:216: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# <ipython-input-11-746900811>:17: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   ad.obs['sample'] = dataset_id
# /usr/local/lib/python3.11/dist-packages/anndata/_core/anndata.py:1897: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# RUN:  0
# ✅ Found Optimal Parameters.
# ✅ Stored distances and conditions in Anndata object.
# Accuracy: 0.5866666666666667
# Precision: 0.5351681957186545
# Recall: 0.9943181818181818
# F1-score: 0.6958250497017893
# AUC: 0.9108966827431609
# AUPR: 0.9052599885622317
# Outlier ratio in reference: 0.01694915254237288
# Outlier ratio in query: 0.8833986928104575
# RUN:  1
# ✅ Found Optimal Parameters.
# ✅ Stored distances and conditions in Anndata object.
# Accuracy: 0.5866666666666667
# Precision: 0.5351681957186545
# Recall: 0.9943181818181818
# F1-score: 0.6958250497017893
# AUC: 0.9108966827431609
# AUPR: 0.9052599885622317
# Outlier ratio in reference: 0.01694915254237288
# Outlier ratio in query: 0.8833986928104575
# RUN:  2
# ✅ Found Optimal Parameters.
# ✅ Stored distances and conditions in Anndata object.
# Accuracy: 0.5866666666666667
# Precision: 0.5351681957186545
# Recall: 0.9943181818181818
# F1-score: 0.6958250497017893
# AUC: 0.9108966827431609
# AUPR: 0.9052599885622317
# Outlier ratio in reference: 0.01694915254237288
# Outlier ratio in query: 0.8833986928104575

# %%
metrics = pd.read_csv(metrics_csv_path)

# %%
metrics
# Out:
#       PROBLEM_KEY  seed  accuracy  precision    recall        f1       auc  \
# 0   ref_0_que_1hr     0  0.422466   0.395779  0.997201  0.566658  0.903255
# 1   ref_0_que_1hr   100  0.422466   0.395779  0.997201  0.566658  0.903255
# 2   ref_0_que_1hr   200  0.422466   0.395779  0.997201  0.566658  0.903255
# 3   ref_0_que_4hr     0  0.622372   0.620664  1.000000  0.765938  0.948549
# 4   ref_0_que_4hr   100  0.622372   0.620664  1.000000  0.765938  0.948549
# 5   ref_0_que_4hr   200  0.622372   0.620664  1.000000  0.765938  0.948549
# 6     ref_0_que_1     0  0.571887   0.557001  0.999503  0.715352  0.944284
# 7     ref_0_que_1   100  0.571887   0.557001  0.999503  0.715352  0.944284
# 8     ref_0_que_1   200  0.571887   0.557001  0.999503  0.715352  0.944284
# 9     ref_0_que_3     0  0.524577   0.459212  1.000000  0.629397  0.915472
# 10    ref_0_que_3   100  0.524577   0.459212  1.000000  0.629397  0.915472
# 11    ref_0_que_3   200  0.524577   0.459212  1.000000  0.629397  0.915472
# 12    ref_0_que_7     0  0.571919   0.512147  0.987572  0.674502  0.792624
# 13    ref_0_que_7   100  0.571919   0.512147  0.987572  0.674502  0.792624
# 14    ref_0_que_7   200  0.571919   0.512147  0.987572  0.674502  0.792624
# 15  ref_0_que_1-7     0  0.586667   0.535168  0.994318  0.695825  0.910897
# 16  ref_0_que_1-7   100  0.586667   0.535168  0.994318  0.695825  0.910897
# 17  ref_0_que_1-7   200  0.586667   0.535168  0.994318  0.695825  0.910897
#
#         aupr  outlier_ratio_ref  outlier_ratio_que  time_taken
# 0   0.849482           0.018462           0.954080   15.881889
# 1   0.849482           0.018462           0.954080   15.947508
# 2   0.849482           0.018462           0.954080   17.127477
# 3   0.964571           0.021792           0.995495   12.391230
# 4   0.964571           0.021792           0.995495   12.429897
# 5   0.964571           0.021792           0.995495   11.828027
# 6   0.953563           0.020278           0.965794   18.472343
# 7   0.953563           0.020278           0.965794   17.453060
# 8   0.953563           0.020278           0.965794   18.060413
# 9   0.890008           0.026029           0.879130   12.018205
# 10  0.890008           0.026029           0.879130   12.016163
# 11  0.890008           0.026029           0.879130   11.962564
# 12  0.770578           0.024516           0.866037   14.460867
# 13  0.770578           0.024516           0.866037   14.500923
# 14  0.770578           0.024516           0.866037   14.554195
# 15  0.905260           0.016949           0.883399   37.125997
# 16  0.905260           0.016949           0.883399   37.055216
# 17  0.905260           0.016949           0.883399   37.027934

# %%
import pandas as pd
import numpy as np
from scipy.stats import sem, t

# Confidence level
confidence = 0.95

# Function to calculate mean ± margin
def mean_margin(series, confidence=0.95):
    n = len(series)
    mean = np.mean(series)
    se = sem(series)
    margin = se * t.ppf((1 + confidence) / 2., n - 1)
    return f"{mean:.4f} ± {margin:.4f}"

# Group by 'Group' and calculate mean ± margin for other columns
grouped = metrics.groupby('PROBLEM_KEY')

result = grouped.agg({
    col: lambda x: mean_margin(x, confidence)
    for col in metrics.columns if col != 'PROBLEM_KEY'
})

# Reset index to make it look cleaner
result.reset_index(inplace=True)

# %%
result
# Out:
#      PROBLEM_KEY                  seed         accuracy        precision  \
# 0    ref_0_que_1  1200.0000 ± 303.7976  0.8469 ± 0.0000  0.8520 ± 0.0000
# 1  ref_0_que_1-7  1200.0000 ± 303.7976  0.7523 ± 0.0000  0.7392 ± 0.0000
# 2  ref_0_que_1hr  1200.0000 ± 303.7976  0.7072 ± 0.0000  0.6316 ± 0.0000
# 3    ref_0_que_3  1200.0000 ± 303.7976  0.6398 ± 0.0000  0.5993 ± 0.0000
# 4  ref_0_que_4hr  1200.0000 ± 303.7976  0.7650 ± 0.0000  0.7401 ± 0.0000
# 5    ref_0_que_7  1200.0000 ± 303.7976  0.6801 ± 0.0000  0.5983 ± 0.0000
#
#             recall               f1              auc             aupr  \
# 0  0.8659 ± 0.0000  0.8589 ± 0.0000  0.9242 ± 0.0000  0.9389 ± 0.0000
# 1  0.7403 ± 0.0000  0.7397 ± 0.0000  0.8253 ± 0.0000  0.8174 ± 0.0000
# 2  0.5438 ± 0.0000  0.5845 ± 0.0000  0.7166 ± 0.0000  0.6639 ± 0.0000
# 3  0.3253 ± 0.0000  0.4217 ± 0.0000  0.6658 ± 0.0000  0.5727 ± 0.0000
# 4  0.9550 ± 0.0000  0.8340 ± 0.0000  0.9298 ± 0.0000  0.9559 ± 0.0000
# 5  0.8757 ± 0.0000  0.7109 ± 0.0000  0.7381 ± 0.0000  0.6501 ± 0.0000
#
#   outlier_ratio_ref outlier_ratio_que        time_taken
# 0   0.0275 ± 0.0000   0.5470 ± 0.0000  26.4938 ± 0.4188
# 1   0.0318 ± 0.0000   0.4762 ± 0.0000  53.1408 ± 0.2811
# 2   0.0711 ± 0.0000   0.3260 ± 0.0000  20.0639 ± 0.1671
# 3   0.0599 ± 0.0000   0.2192 ± 0.0000  14.5745 ± 0.1689
# 4   0.0372 ± 0.0000   0.7973 ± 0.0000  14.2394 ± 0.1501
# 5   0.0342 ± 0.0000   0.6574 ± 0.0000  18.0617 ± 0.3858

# %%
result.to_csv(results_csv_path, index=False)
